# %% [markdown]
# <a href="https://colab.research.google.com/github/anushageddam/PRODIGY_WD_04/blob/main/WD_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.core.display import display, HTML

# HTML, CSS, and JavaScript code for the Personal Portfolio
html_code = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>My Portfolio</title>
    <style>
        body {
            font-family: 'Arial', sans-serif;
            margin: 0;
            padding: 0;
            background-color: #1e1e2f; /* Darker background for better contrast */
            color: #f4f4f9; /* Light text for readability */
        }
        header {
            background-color: #007bff;
            color: white;
            padding: 20px 0;
            text-align: center;
        }
        header h1 {
            margin: 0;
            font-size: 2.5rem;
        }
        header p {
            margin: 5px 0;
            font-size: 1.2rem;
        }
        .container {
            width: 80%;
            margin: 20px auto;
        }
        section {
            margin-bottom: 30px;
        }
        section h2 {
            font-size: 2rem;
            color: #ffa726; /* Accent color for section titles */
            margin-bottom: 10px;
        }
        .about, .skills, .projects {
            background: #2b2b3c; /* Contrast card background */
            padding: 20px;
            border-radius: 10px;
            box-shadow: 0 0 10px rgba(0, 0, 0, 0.3);
        }
        .skills ul, .projects ul {
            list-style: none;
            padding: 0;
        }
        .skills ul li, .projects ul li {
            margin: 5px 0;
            font-size: 1.1rem;
        }
        .projects ul li a {
            color: #ffa726; /* Accent color for links */
            text-decoration: none;
            transition: color 0.3s;
        }
        .projects ul li a:hover {
            color: #ff5722; /* Hover effect for links */
        }
        footer {
            background-color: #333;
            color: white;
            text-align: center;
            padding: 10px 0;
        }
        footer p {
            margin: 0;
            font-size: 1rem;
        }
    </style>
</head>
<body>
    <header>
        <h1>Welcome to My Portfolio</h1>
        <p>Web Developer | Problem Solver | Lifelong Learner</p>
    </header>
    <div class="container">
        <section class="about">
            <h2>About Me</h2>
            <p>Hello! I’m [Your Name], a passionate web developer specializing in creating dynamic and user-friendly websites. With a background in [your education], I have honed my skills in HTML, CSS, JavaScript, and more. I’m always eager to learn and explore new technologies to enhance my craft.</p>
        </section>
        <section class="skills">
            <h2>Skills</h2>
            <ul>
                <li>HTML, CSS, JavaScript</li>
                <li>React.js & Node.js</li>
                <li>Python & Flask</li>
                <li>SQL & MongoDB</li>
                <li>Responsive Design</li>
            </ul>
        </section>
        <section class="projects">
            <h2>Projects</h2>
            <ul>
                <li><a href="#">Stopwatch Web Application</a> - A responsive and interactive timer application.</li>
                <li><a href="#">Tic-Tac-Toe Game</a> - A classic two-player game built with JavaScript.</li>
                <li><a href="#">Weather App</a> - Real-time weather updates using APIs.</li>
            </ul>
        </section>
    </div>
    <footer>
        <p>© 2024 [Your Name]. All rights reserved.</p>
    </footer>
</body>
</html>
"""

# Render the HTML code in Google Colab
display(HTML(html_code))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>My Portfolio</title>
#     <style>
#         body {
#             font-family: 'Arial', sans-serif;
#             margin: 0;
#             padding: 0;
#             background-color: #1e1e2f; /* Darker background for better contrast */
#             color: #f4f4f9; /* Light text for readability */
#         }
#         header {
#             background-color: #007bff;
#             color: white;
#             padding: 20px 0;
#             text-align: center;
#         }
#         header h1 {
#             margin: 0;
#             font-size: 2.5rem;
#         }
#         header p {
#             margin: 5px 0;
#             font-size: 1.2rem;
#         }
#         .container {
#             width: 80%;
#             margin: 20px auto;
#         }
#         section {
#             margin-bottom: 30px;
#         }
# ...
